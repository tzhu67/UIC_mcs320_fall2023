# %%
import pandas as pd
title = ['Deadline', 'Institute', 'Link', 'Internal']
# Internal = via MathJobs, AcademicJobs and Interfolio
# Add 'Advisor', 'Replyer', 'Applied', 'Accepted' etc

# %%
job = [['2025/08/01', '复旦大学', 'https://www.mathjobs.org/jobs/list/20086', False]]
job.append(['2024/12/09', '中山大学', 'https://www.mathjobs.org/jobs/list/22438', False])
job.append(['2024/12/30', '浙江大学', 'https://www.mathjobs.org/jobs/list/23473', True])
job.append(['2024/12/24', 'Universidad de Chile', 'https://www.mathjobs.org/jobs/list/23937', False])
job.append(['2024/11/08', 'University of South Carolina', 'https://www.mathjobs.org/jobs/list/24070', True])
job.append(['2024/11/15', 'Florida State University', 'https://www.mathjobs.org/jobs/list/24311', True])
job.append(['2024/09/31', 'University of South Carolina', 'https://www.mathjobs.org/jobs/list/24336', True])
job.append(['', '武汉大学', 'https://www.mathjobs.org/jobs/list/24432', False])
job.append(['2024/11/15', 'University of Alberta', 'https://www.mathjobs.org/jobs/list/24578', True])
job.append(['', 'Los Alamos National Laboratory', 'https://www.mathjobs.org/jobs/list/24627', False])
job.append(['2024/12/01', 'Institute for Advanced Study', 'https://www.mathjobs.org/jobs/list/24628', True])
job.append(['2025/01/10', '上海科技大学', 'https://www.mathjobs.org/jobs/list/24659', True])
job.append(['2025/06/20', 'University of Texas', 'https://www.mathjobs.org/jobs/list/24740', False])
job.append(['2025/06/26', '北京师范大学', 'https://www.mathjobs.org/jobs/list/24770', False])
job.append(['2025/06/30', '北京师范大学珠海分校', 'https://www.mathjobs.org/jobs/list/24771', False])
job.append(['2025/07/20', 'Princeton University', 'https://www.mathjobs.org/jobs/list/24843', True])
job.append(['2024/12/15', 'University of Michigan', 'https://www.mathjobs.org/jobs/list/24874', True])
job.append(['2024/10/31', 'University of Bonn', 'https://www.mathjobs.org/jobs/list/24941', True])
job.append(['2024/09/20', 'Aarhus University', 'https://www.mathjobs.org/jobs/list/24955', False])
job.append(['2024/12/01', 'Harvard University', 'https://www.mathjobs.org/jobs/list/24959', False])
job.append(['2024/12/01', 'University of California, Davis', 'https://www.mathjobs.org/jobs/list/24963', False])
job.append(['2024/11/10', 'University of Manitoba', 'https://www.mathjobs.org/jobs/list/24973', True])
job.append(['', 'Radix Trading LLC Chicago', 'https://www.mathjobs.org/jobs/list/24691', True])
job.append(['', 'Radix Trading LLC Amsterdam', 'https://www.mathjobs.org/jobs/list/24692', True])
job.append(['2024/10/21', 'Jane Street Capital', 'https://www.mathjobs.org/jobs/list/24956', False])
job.append(['', '哈尔滨工程大学', 'https://www.mathjobs.org/jobs/list/24232', True])
job.append(['', '东南大学', 'https://www.mathjobs.org/jobs/list/19700', True])
job.append(['', '上海数学与交叉学科研究院', 'https://www.mathjobs.org/jobs/list/24069', True])
job.append(['', 'PDT Partners', 'https://www.mathjobs.org/jobs/list/24400', True])
job.append(['', 'Williams College', 'https://www.mathjobs.org/jobs/list/24919', True])
job.append(['2025/01/05', 'New Mexico State University', 'https://www.mathjobs.org/jobs/list/24979', True])
job.append(['', 'North Carolina State University', 'https://www.mathjobs.org/jobs/list/24989', True])
job.append(['2024/10/15', 'Yale University, Wu Tsai Institute', 'https://www.mathjobs.org/jobs/list/24999', False])
job.append(['2024/10/31', 'Brookhaven National Laboratory', 'https://bnl.wd1.myworkdayjobs.com/en-US/Externa/', False])
job.append(['2025/08/31', '清华大学丘成桐数学科学中心', 'https://www.mathjobs.org/jobs/list/25014', True])
job.append(['', '北京大学', 'https://www.mathjobs.org/jobs/list/25018', True])
job.append(['2024/12/01', 'University of Texas at Austin', 'https://www.mathjobs.org/jobs/list/25026', False])
job.append(['2024/11/04', 'Brown University', 'https://www.mathjobs.org/jobs/list/24858', True])
job.append(['2024/09/19', 'University of Edinburgh', 'https://www.mathjobs.org/jobs/list/24998', False])
job.append(['2024/10/31', 'Concordia University', 'https://www.mathjobs.org/jobs/list/25000', True])
job.append(['2025/06/30', 'Michigan State University', 'https://www.mathjobs.org/jobs/list/25022', True])
job.append(['2024/12/01', 'Cornell University', 'https://www.mathjobs.org/jobs/list/25031', True])
job.append(['2024/12/13', 'Yale University', 'https://www.mathjobs.org/jobs/list/25032', True])
job.append(['2024/10/27', 'Universidad de Chile', 'https://www.mathjobs.org/jobs/list/25043', False])
job.append(['2024/10/01', 'Utah State University', 'https://www.mathjobs.org/jobs/list/25044', False])
job.append(['2025/05/31', 'University of Utah', 'https://www.mathjobs.org/jobs/list/25058', False])
job.append(['2024/12/01', 'University of Minnesota', 'https://www.mathjobs.org/jobs/list/25085', True])
job.append(['2024/11/01', 'University of Maryland', 'https://www.mathjobs.org/jobs/list/25086', True])
job.append(['', '南京师范大学', 'https://www.mathjobs.org/jobs/list/25108', True])
job.append(['2024/11/15', 'University of Minnesota', 'https://www.mathjobs.org/jobs/list/25118', True])
job.append(['2024/11/15', 'Texas A&M University', 'https://www.mathjobs.org/jobs/list/25120', False])
job.append(['2024/11/10', 'Centre de recherches mathématiques', 'https://www.mathjobs.org/jobs/list/25133', True])
job.append(['2025/01/05', 'Dartmouth College', 'https://www.mathjobs.org/jobs/list/25166', True])
job.append(['', 'Syracuse University', 'https://www.mathjobs.org/jobs/list/25163', True])
job.append(['2025/09/15', '哈尔滨工业大学', 'https://www.mathjobs.org/jobs/list/23063', False])
job.append(['2024/12/01', '香港中文大学', 'https://www.mathjobs.org/jobs/list/25141', True])
job.append(['2024/12/15', 'University of Massachusetts Amherst', 'https://www.mathjobs.org/jobs/list/25137', True])
job.append(['', 'Susquehanna International Group', 'https://www.mathjobs.org/jobs/list/25153', False])
job.append(['2024/10/31', 'WIAS Berlin', 'https://www.mathjobs.org/jobs/list/24968', False])
job.append(['2024/12/01', 'University of Ottawa', 'https://www.mathjobs.org/jobs/list/25200', True])
job.append(['2025/05/01', 'Rutgers University', 'https://www.mathjobs.org/jobs/list/25204', True])
job.append(['2024/12/01', 'Massachusetts Institute of Technology', 'https://www.mathjobs.org/jobs/list/25210', True])
job.append(['2024/11/15', 'University of Copenhagen', 'https://www.mathjobs.org/jobs/list/25211', True])
job.append(['2024/12/15', 'Pennsylvania State University', 'https://www.mathjobs.org/jobs/list/25217', True])
job.append(['2024/11/15', 'Carnegie Mellon University', 'https://www.mathjobs.org/jobs/list/25218', True])
job.append(['2025/10/20', '南方科技大学', 'https://www.mathjobs.org/jobs/list/25223', True])
job.append(['2024/11/30', 'Purdue University', 'https://www.mathjobs.org/jobs/list/25225', True])
job.append(['2024/12/01', 'University of Oregon', 'https://www.mathjobs.org/jobs/list/24921', True])
job.append(['2024/11/15', 'Ecole Polytechnique Fédérale de Lausanne', 'https://www.mathjobs.org/jobs/list/25241', False])
job.append(['2025/10/31', '复旦大学上海数学中心', 'https://www.mathjobs.org/jobs/list/25253', True])
job.append(['', '上海纽约大学', 'https://www.mathjobs.org/jobs/list/25262', False])
job.append(['2025/09/23', 'University of California, San Diego', 'https://www.mathjobs.org/jobs/list/25263', True])
job.append(['2025/03/15', 'Bilkent University', 'https://www.mathjobs.org/jobs/list/25272', True])
job.append(['2024/11/01', 'Georgia Institute of Technology', 'https://www.mathjobs.org/jobs/list/25280', True])
job.append(['2024/12/01', 'Dartmouth College', 'https://www.mathjobs.org/jobs/list/25309', True])
job.append(['2024/12/01', 'University of Illinois at Urbana-Champaign', 'https://www.mathjobs.org/jobs/list/25304', True])
job.append(['2025/01/01', 'University of Washington', 'https://www.mathjobs.org/jobs/list/25293', True])
job.append(['2025/03/31', 'University of British Columbia', 'https://www.mathjobs.org/jobs/list/25286', True])
job.append(['2024/11/01', 'University of Saskatchewan', 'https://www.mathjobs.org/jobs/list/25313', True])
job.append(['2024/11/01', 'University of Münster', 'https://www.mathjobs.org/jobs/list/25325', False])
job.append(['2025/01/01', 'Fields Institute', 'https://www.mathjobs.org/jobs/list/25329', True])
job.append(['2024/11/01', 'ETH Zurich', 'https://www.mathjobs.org/jobs/list/25327', True])
job.append(['2025/06/30', 'University of California, Irvine', 'https://www.mathjobs.org/jobs/list/25339', False])
job.append(['2025/09/30', 'Yale University', 'https://www.mathjobs.org/jobs/list/25340', False])
job.append(['2024/12/31', 'University of Massachusetts Lowell', 'https://www.mathjobs.org/jobs/list/25358', False])
job.append(['2025/01/17', 'Queen\'s University', 'https://www.mathjobs.org/jobs/list/25355', True])
job.append(['2024/11/25', 'University of Waterloo', 'https://www.mathjobs.org/jobs/list/25347', True])
job.append(['2024/12/01', 'Carnegie Mellon University', 'https://www.mathjobs.org/jobs/list/25379', True])
job.append(['2024/12/01', 'University of Texas at Arlington', 'https://www.mathjobs.org/jobs/list/25392', True])
job.append(['2024/12/04', 'Oak Ridge National Laboratory', 'https://www.mathjobs.org/jobs/list/25393', False])
job.append(['2024/11/15', 'Princeton University', 'https://www.mathjobs.org/jobs/list/25398', True])
job.append(['2024/12/30', '浙江大学', 'https://www.mathjobs.org/jobs/list/25399', True])
job.append(['2025/05/02', 'Université libre de Bruxelles', 'https://www.mathjobs.org/jobs/list/25403', False])
job.append(['2024/11/15', 'University of Tennessee', 'https://www.mathjobs.org/jobs/list/25406', False])
job.append(['2024/12/01', 'New York University', 'https://www.mathjobs.org/jobs/list/25435', False])
job.append(['2024/12/01', 'Technische Universität Berlin', 'https://www.mathjobs.org/jobs/list/25451', False])
job.append(['2024/12/15', 'Georgetown University', 'https://www.mathjobs.org/jobs/list/25460', False])
job.append(['2024/12/06', 'University of Chicago', 'https://www.mathjobs.org/jobs/list/25462', False])
job.append(['2024/11/07', 'Columbia University', 'https://www.mathjobs.org/jobs/list/25473', False])
job.append(['2024/11/10', 'Umeå University', 'https://www.mathjobs.org/jobs/list/25478', False])
job.append(['2024/12/31', 'Technical University of Munich', 'https://www.mathjobs.org/jobs/list/25479', False])
job.append(['2024/11/16', 'Imperial College London', 'https://www.mathjobs.org/jobs/list/25487', False])
job.append(['2024/11/15', 'University of Victoria', 'https://www.mathjobs.org/jobs/list/25496', True])
job.append(['', 'Worcester Polytechnic Institute', 'https://www.mathjobs.org/jobs/list/25507', False])
job.append(['', 'Louisiana State University', 'https://www.mathjobs.org/jobs/list/25510', True])
job.append(['2024/12/15', 'Johns Hopkins University', 'https://www.mathjobs.org/jobs/list/25515', True])
job.append(['', 'Claremont Graduate University', 'https://www.mathjobs.org/jobs/list/25524', True])
job.append(['2024/11/30', 'Northwestern University', 'https://www.mathjobs.org/jobs/list/25527', True])
job.append(['2024/12/15', 'The University of Arizona', 'https://www.mathjobs.org/jobs/list/25532', True])
job.append(['2024/11/15', 'Florida State University', 'https://www.mathjobs.org/jobs/list/25544', True])
job.append(['2024/11/15', 'University of Colorado at Boulder', 'https://www.mathjobs.org/jobs/list/25550', False])
job.append(['2025/01/31', 'Pennsylvania State University', 'https://www.mathjobs.org/jobs/list/25553', True])
job.append(['202024/12/31', '清华大学北京雁栖湖应用数学研究院', 'https://www.mathjobs.org/jobs/list/25562', True])
job.append(['2024/12/05', 'Johns Hopkins University', 'https://www.mathjobs.org/jobs/list/25569', False])
job.append(['2024/12/16', 'Atlantic Association for Research in the Mathematical Sciences', 'https://www.mathjobs.org/jobs/list/25576', False])
job.append(['2024/12/01', 'Purdue University', 'https://www.mathjobs.org/jobs/list/25577', True])
job.append(['2024/12/01', 'University of Missouri-Columbia', 'https://www.mathjobs.org/jobs/list/25587', False])
job.append(['2024/11/22', 'University of Oxford', 'https://www.mathjobs.org/jobs/list/25590', False])
job.append(['2024/12/01', 'Max Planck Institute of Molecular Cell Biology and Genetics', 'https://www.mathjobs.org/jobs/list/25591', False])
job.append(['2024/12/13', 'University of California, Riverside', 'https://www.mathjobs.org/jobs/list/25599', False])
job.append(['2024/10/31', 'Lawrence Berkeley National Laboratory', 'https://lbl.taleo.net/careersection/2/mysubmissions.ftl?lang=en', False])
job.append(['2024/11/15', 'University of California, Los Angeles', 'https://recruit.apo.ucla.edu/JPF09878', False])
job.append(['2024/12/31', 'IBM Research', 'https://academicjobsonline.org/ajo/jobs/28565', False])
job.append(['2024/12/01', 'University of Tokyo', 'https://academicjobsonline.org/ajo/jobs/28285', False])
job.append(['2024/12/01', 'Trinity College Dublin', 'https://academicjobsonline.org/ajo/jobs/28443', False])
job.append(['2025/01/15', 'University of California, San Diego', 'https://academicjobsonline.org/ajo/jobs/28847', False])
job.append(['2024/12/15', 'University of Notre Dame', 'https://www.mathjobs.org/jobs/list/25607', True])
job.append(['2025/05/31', 'University of Southern California', 'https://www.mathjobs.org/jobs/list/25610', True])
job.append(['2024/11/25', 'University of California, Berkeley', 'https://aprecruit.berkeley.edu/JPF04597', False])
job.append(['2024/12/15', 'University of Arkansas', 'https://www.mathjobs.org/jobs/list/25636', False])
job.append(['', 'Louisiana State University', 'https://www.mathjobs.org/jobs/list/25644', True])
job.append(['2024/12/01', 'Rice University', 'https://www.mathjobs.org/jobs/list/25646', True])
job.append(['2024/12/08', 'Fondation Mathématiques Jacques Hadamard', 'https://www.mathjobs.org/jobs/list/25648', False])
job.append(['2024/12/03', 'Institut des Hautes Etudes Scientifiques', 'https://www.ihes.fr/en/applications/post-docs/huawei-young-talents-programme/', False])
job.append(['2024/12/01', 'University of Texas at Austin', 'https://www.mathjobs.org/jobs/list/25662', False])
job.append(['2024/12/01', 'University of Texas at Austin', 'https://www.mathjobs.org/jobs/list/25667', False])
job.append(['2024/12/09', 'Temple University', 'https://www.mathjobs.org/jobs/list/25671', True])
job.append(['2024/11/15', 'University of Virginia', 'https://www.mathjobs.org/jobs/list/25676', True])
job.append(['2024/12/08', 'Universidad de Los Andes', 'https://www.mathjobs.org/jobs/list/25678', False])
job.append(['2025/06/30', 'University of California, San Diego', 'https://www.mathjobs.org/jobs/list/25700', False])
job.append(['', '北京大学', 'https://www.mathjobs.org/jobs/list/25703', True])
job.append(['2025/01/07', 'University College Dublin', 'https://www.mathjobs.org/jobs/list/25705', False])
job.append(['2024/12/20', 'University of Edinburgh', 'https://www.mathjobs.org/jobs/list/25691', False])
job.append(['2025/01/01', 'California Institute of Technology', 'https://www.mathjobs.org/jobs/list/25693', False])
job.append(['2024/12/02', 'Georgetown College', 'https://www.mathjobs.org/jobs/list/25697', False])
job.append(['2024/12/15', 'Simons Foundation/Flatiron Institute', 'https://www.mathjobs.org/jobs/list/25686', False])
job.append(['2025/01/04', 'Brown University', 'https://www.mathjobs.org/jobs/list/25689', True])
job.append(['2024/12/09', 'Fondation Mathématiques Jacques Hadamard', 'https://www.mathjobs.org/jobs/list/25717', False])
job.append(['', 'North Carolina State University', 'https://www.mathjobs.org/jobs/list/25719', True])
job.append(['2024/12/06', 'University of Michigan', 'https://www.mathjobs.org/jobs/list/25725', False])
job.append(['2024/12/02', 'University of Nebraska-Lincoln', 'https://www.mathjobs.org/jobs/list/25729', True])
job.append(['2024/11/15', 'Vanderbilt University', 'https://www.mathjobs.org/jobs/list/25731', True])
job.append(['2025/01/15', 'Wake Forest University', 'https://www.mathjobs.org/jobs/list/25737', True])
job.append(['', 'Baylor University', 'https://www.mathjobs.org/jobs/list/25740', True])
job.append(['2025/01/12', 'University of Oklahoma', 'https://www.mathjobs.org/jobs/list/25745', True])
job.append(['2025/01/03', 'McMaster University', 'https://www.mathjobs.org/jobs/list/25750', True])
job.append(['2024/12/13', 'McMaster University', 'https://www.mathjobs.org/jobs/list/25753', True])
job.append(['2024/12/31', 'University of Georgia', 'https://www.mathjobs.org/jobs/list/25755', True])
job.append(['2024/12/31', 'University of Georgia', 'https://www.mathjobs.org/jobs/list/25756', True])
job.append(['2025/01/12', 'University of Florida', 'https://www.mathjobs.org/jobs/list/25758', True])
job.append(['2025/01/06', 'University of Pennsylvania', 'https://www.mathjobs.org/jobs/list/25765', True])
job.append(['2024/10/18', 'Simons Foundation/Flatiron Institute', 'https://www.mathjobs.org/jobs/list/25768', False])
job.append(['2025/01/06', 'Oak Ridge National Laboratory', 'https://www.mathjobs.org/jobs/list/25780', False])
job.append(['2025/03/28', 'Rice University', 'https://www.mathjobs.org/jobs/list/25781', True])
job.append(['2024/12/01', 'Fordham University', 'https://www.mathjobs.org/jobs/list/25785', True])
job.append(['', 'Fortress Investment Group', 'https://www.mathjobs.org/jobs/list/25786', False])
job.append(['2025/11/30', '中山大学', 'https://www.mathjobs.org/jobs/list/25791', True])
job.append(['2025/01/15', 'Virginia Tech', 'https://www.mathjobs.org/jobs/list/25792', False])
job.append(['2024/12/10', 'Virginia Tech', 'https://www.mathjobs.org/jobs/list/25793', False])
job.append(['2024/12/20', 'University of Illinois at Chicago', 'https://www.mathjobs.org/jobs/list/25799', True])
job.append(['2025/01/06', 'University of North Texas', 'https://www.mathjobs.org/jobs/list/25800', False])
job.append(['2025/01/15', 'Case Western Reserve University', 'https://www.mathjobs.org/jobs/list/25807', False])
job.append(['2025/01/15', 'Simons Foundation/Flatiron Institute', 'https://www.mathjobs.org/jobs/list/25834', False])
job.append(['2025/08/31', 'Colorado State University', 'https://www.mathjobs.org/jobs/list/25835', False])
job.append(['2024/12/01', 'Northeastern University', 'https://www.mathjobs.org/jobs/list/25839', True])
job.append(['2024/12/15', 'SUNY at Buffalo', 'https://www.mathjobs.org/jobs/list/25842', True])
job.append(['2024/12/09', 'University of Toronto', 'https://www.mathjobs.org/jobs/list/25840', True])
job.append(['', '中国科学技术大学', 'https://www.mathjobs.org/jobs/list/25853', True])
job.append(['2024/12/10', 'Clemson University', 'https://www.mathjobs.org/jobs/list/25872', False])
job.append(['2024/12/13', 'University of Toronto', 'https://www.mathjobs.org/jobs/list/25865', True])
job.append(['2024/12/20', 'Indiana University Bloomington', 'https://www.mathjobs.org/jobs/list/25866', True])
job.append(['2024/12/11', 'Cornell University', 'https://www.mathjobs.org/jobs/list/25862', False])
job.append(['2025/05/17', '中国科学技术大学', 'https://www.mathjobs.org/jobs/list/25880', True])
job.append(['2024/12/01', 'Rutgers University', 'https://www.mathjobs.org/jobs/list/25895', True])
job.append(['2024/12/16', 'University of Bristol', 'https://www.mathjobs.org/jobs/list/25897', False])
job.append(['2025/01/06', 'University of South Florida', 'https://www.mathjobs.org/jobs/list/25904', True])
job.append(['2025/01/12', 'University of Melbourne', 'https://www.mathjobs.org/jobs/list/25908', False])
job.append(['2025/01/03', 'University of Edinburgh', 'https://www.mathjobs.org/jobs/list/25910', False])
job.append(['2024/12/31', 'UT MD Anderson Cancer Center', 'https://www.mathjobs.org/jobs/list/25913', False])
job.append(['2025/01/06', 'University of Minnesota-Duluth', 'https://www.mathjobs.org/jobs/list/25914', False])
job.append(['2025/01/31', 'Earlham College', 'https://www.mathjobs.org/jobs/list/25924', False])
job.append(['2024/12/15', 'University of Maryland Baltimore County', 'https://www.mathjobs.org/jobs/list/25929', True])
job.append(['2024/12/22', 'University of Chicago', 'https://www.mathjobs.org/jobs/list/25931', True])
job.append(['2025/02/03', 'Smith College', 'https://www.mathjobs.org/jobs/list/25932', True])
job.append(['2024/12/22', 'Arizona State University', 'https://www.mathjobs.org/jobs/list/25933', True])
job.append(['2025/01/15', 'Trinity College', 'https://www.mathjobs.org/jobs/list/25937', True])
job.append(['', '西湖大学', 'https://www.mathjobs.org/jobs/list/25939', True])
job.append(['2025/01/03', 'University of Edinburgh', 'https://www.mathjobs.org/jobs/list/25940', False])
job.append(['2024/12/24', 'Arizona State University', 'https://www.mathjobs.org/jobs/list/25941', True])
job.append(['2025/01/20', 'University of Tennessee', 'https://www.mathjobs.org/jobs/list/25944', True])
job.append(['2024/12/20', 'University of Sydney', 'https://www.mathjobs.org/jobs/list/25946', False])
job.append(['2025/01/10', 'Virginia Tech', 'https://www.mathjobs.org/jobs/list/25958', False])
job.append(['2025/01/10', 'Virginia Tech', 'https://www.mathjobs.org/jobs/list/25957', False])
job.append(['2025/01/31', 'University College London', 'https://www.mathjobs.org/jobs/list/25960', False])
job.append(['2025/05/30', 'University of Oklahoma', 'https://www.mathjobs.org/jobs/list/25962', True])
job.append(['2025/01/21', 'University of Bergen', 'https://www.jobbnorge.no/en/available-jobs/job/272608/postdoctoral-research-fellow-position-in-computational-geoscience', False])
job.append(['2025/01/15', 'Rensselaer Polytechnic Institute', 'https://www.mathjobs.org/jobs/list/26032', True])
job.append(['2025/01/31', 'Grinnell College', 'https://www.mathjobs.org/jobs/list/26033', False])
job.append(['', 'Pennsylvania State University', 'https://www.mathjobs.org/jobs/list/26034', True])
job.append(['2025/02/01', 'University of Calgary', 'https://www.mathjobs.org/jobs/list/25999', False])
job.append(['2025/01/15', 'University of Tuebingen', 'https://www.mathjobs.org/jobs/list/26001', True])
job.append(['2025/02/01', 'University of Minnesota-Twin Cities', 'https://www.mathjobs.org/jobs/list/26011', False])
job.append(['2025/03/17', 'Université Côte d\'Azur', 'https://www.mathjobs.org/jobs/list/26017', False])
job.append(['2025/06/10', 'Tulane University', 'https://www.mathjobs.org/jobs/list/25980', False])
job.append(['2024/12/31', 'Iowa State University', 'https://www.mathjobs.org/jobs/list/25982', True])
job.append(['2025/01/15', 'University of Waterloo', 'https://www.mathjobs.org/jobs/list/25969', True])
job.append(['2025/01/13', 'University of Queensland', 'https://www.mathjobs.org/jobs/list/25970', False])
job.append(['2025/01/08', 'University of Pisa', 'https://www.mathjobs.org/jobs/list/25971', False])
job.append(['2025/01/05', 'Aarhus University', 'https://www.mathjobs.org/jobs/list/25972', False])
job.append(['2025/01/06', 'University of Melbourne', 'https://www.mathjobs.org/jobs/list/25976', True])
job.append(['2025/01/21', 'University of Bergen', 'https://www.mathjobs.org/jobs/list/26082', False])
job.append(['2025/01/19', 'Technische Universität Ilmenau', 'https://www.mathjobs.org/jobs/list/26084', False])
job.append(['2025/01/15', 'Pennsylvania State University', 'https://www.mathjobs.org/jobs/list/26092', True])
job.append(['2025/02/28', 'Alfred Renyi Institute', 'https://www.mathjobs.org/jobs/list/26075', False])
job.append(['2025/01/31', 'New Jersey Institute of Technology', 'https://www.mathjobs.org/jobs/list/26059', False])
job.append(['2025/01/31', 'Universite Paul Sabatier', 'https://www.mathjobs.org/jobs/list/26061', False])
job.append(['2025/01/05', 'University of Bath', 'https://www.mathjobs.org/jobs/list/26052', False])
job.append(['2025/02/28', 'University of Sheffield', 'https://www.mathjobs.org/jobs/list/26053', False])
job.append(['2025/02/18', 'University of Sydney', 'https://www.mathjobs.org/jobs/3370/SMRIIVP', False])
job.append(['2025/01/30', 'Centre College', 'https://www.mathjobs.org/jobs/list/26039', True])
job.append(['2025/03/01', 'Colorado School of Mines', 'https://www.mathjobs.org/jobs/list/26040', False])
job.append(['2025/01/20', 'Institut de Mathématiques de Jussieu-Paris Rive Gauche', 'https://www.mathjobs.org/jobs/list/26114', True])
job.append(['2025/01/15', 'National Institute for Theory and Mathematics in Biology', 'https://www.mathjobs.org/jobs/list/26116', True])
job.append(['2025/02/17', 'Bowdoin College', 'https://www.mathjobs.org/jobs/list/26117', True])
job.append(['2025/01/15', 'Scuola Normale Superiore', 'https://www.mathjobs.org/jobs/list/26096', False])
job.append(['2025/01/15', 'Brandeis University', 'https://www.mathjobs.org/jobs/list/26104', True])
job.append(['2025/01/31', 'Yale University', 'https://www.mathjobs.org/jobs/list/26123', False])
job.append(['', 'Université Côte d\'Azur', 'https://www.mathjobs.org/jobs/list/26090', False])
job.append(['', 'Ohio State University', 'https://www.mathjobs.org/jobs/list/26074', False])
job.append(['', 'Ohio State University', 'https://www.mathjobs.org/jobs/list/26076', False])
jobs = pd.DataFrame(job, columns=title)
# Updated 2024/12/24, below Yale University, Yale CADMY
# SIAM by The Hong Kong Polytechnic University
# job.append(['', '', '', True])
# jobs = pd.concat([pd.DataFrame(job, columns=title), jobs], ignore_index=True) # for appending jobs in separate cells

# %%
# Applications
applieDate = '2024/12/30'
jobs['Applied'] = [False for i in range(jobs.shape[0])]
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Columbia University'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Lawrence Berkeley National Laboratory'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='WIAS Berlin'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Brookhaven National Laboratory'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Münster'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Umeå University'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Bonn'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Concordia University'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Maryland'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Georgia Institute of Technology'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Saskatchewan'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='ETH Zurich'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Brown University'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='North Carolina State University'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Simons Foundation/Flatiron Institute'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of South Carolina'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Centre de recherches mathématiques'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Manitoba'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Baylor University'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='哈尔滨工程大学'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Williams College'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Louisiana State University'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Syracuse University'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Claremont Graduate University'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Worcester Polytechnic Institute'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Tennessee'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Texas A&M University'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Ecole Polytechnique Fédérale de Lausanne'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Colorado at Boulder'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Imperial College London'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Oxford'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of California, Los Angeles'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of California, Berkeley'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Vanderbilt University'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Copenhagen'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Carnegie Mellon University'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Victoria'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Virginia'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Florida State University'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Minnesota'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Princeton University'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Alberta'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Waterloo'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Northwestern University'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Purdue University'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Los Alamos National Laboratory'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Ottawa'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Illinois at Urbana-Champaign'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Dartmouth College'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Rice University'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Texas at Arlington'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Oregon'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Massachusetts Institute of Technology'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='香港中文大学'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Fordham University'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Cornell University'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Northeastern University'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Institute for Advanced Study'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Nebraska-Lincoln'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Temple University'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Toronto'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Yale University	'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='McMaster University'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Tokyo'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Trinity College Dublin'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Rutgers University'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Technische Universität Berlin'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Texas at Austin'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Missouri-Columbia'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Johns Hopkins University'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Virginia Tech'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Clemson University'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of California, Davis'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of California, Riverside'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Maryland Baltimore County'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='The University of Arizona'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Massachusetts Amherst'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='SUNY at Buffalo'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Michigan'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Pennsylvania State University'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Arkansas'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Notre Dame'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Georgetown University'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Indiana University Bloomington'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Sydney'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Edinburgh'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Arizona State University'),'Applied'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Chicago'),'Applied'] = True
#jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute==''),'Applied'] = True
#jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute==''),'Applied'] = True
# jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute==''),'Applied'] = True
# Awaiting
jobs[jobs.Applied].shape[0]
# Out:
# 105

# %%
# Todo List
jobs = jobs[(jobs.Deadline=='')|(jobs.Deadline>='2024/12/31')]
jobs.sort_values(by=['Deadline'], inplace = True)
toDo = jobs[(jobs.Deadline!='')&(jobs.Deadline<='2024/12/31')]
toDo#[toDo.Internal]
# Out:
#        Deadline                           Institute  \
# 122  2024/12/31                        IBM Research
# 214  2024/12/31               Iowa State University
# 157  2024/12/31               University of Georgia
# 158  2024/12/31               University of Georgia
# 188  2024/12/31        UT MD Anderson Cancer Center
# 100  2024/12/31      Technical University of Munich
# 84   2024/12/31  University of Massachusetts Lowell
#
#                                               Link  Internal  Applied
# 122  https://academicjobsonline.org/ajo/jobs/28565     False    False
# 214       https://www.mathjobs.org/jobs/list/25982      True    False
# 157       https://www.mathjobs.org/jobs/list/25755      True    False
# 158       https://www.mathjobs.org/jobs/list/25756      True    False
# 188       https://www.mathjobs.org/jobs/list/25913     False    False
# 100       https://www.mathjobs.org/jobs/list/25479     False    False
# ...

# %%
# links to fill
#toDo[toDo.Internal].Link
toDo.Link
# Out:
# 122    https://academicjobsonline.org/ajo/jobs/28565
# 214         https://www.mathjobs.org/jobs/list/25982
# 157         https://www.mathjobs.org/jobs/list/25755
# 158         https://www.mathjobs.org/jobs/list/25756
# 188         https://www.mathjobs.org/jobs/list/25913
# 100         https://www.mathjobs.org/jobs/list/25479
# 84          https://www.mathjobs.org/jobs/list/25358
# Name: Link, dtype: object

# %%
# Writers may expect letter requests from
title = ['Institute', 'Website']
#emailsExpected = [['Lawrence Berkeley National Laboratory', 'www.lbl.gov']]
#emailsExpected.append(['Weierstrass Institute', 'www.wias-berlin.de'])
#emailsExpected.append(['Brookhaven National Laboratory', 'www.bnl.gov'])
#emailsExpected.append(['Umeå University', 'umustipendie.varbi.com'])
#emailsExpected.append(['Columbia University', 'www.interfolio.com'])
#emailsExpected = [['University of Tennessee', 'ut.taleo.net']]
#emailsExpected.append(['Ecole Polytechnique Fédérale de Lausanne', 'www.epfl.ch'])
#emailsExpected.append(['University of Colorado at Boulder', 'jobs.colorado.edu'])
#emailsExpected.append(['University of California, Los Angeles', 'recruit.apo.ucla.edu'])
#emailsExpected.append(['University of California, Berkeley', 'aprecruit.berkeley.edu'])
#emailsExpected.append(['Imperial College London', 'www.imperial.ac.uk'])
#emailsExpected.append(['University of Oxford', 'corehr.com'])
#emailsExpected = [['Technische Universität Berlin', 'www.math-berlin.de']]
#emailsExpected.append(['Institut des Hautes Etudes Scientifiques', 'gestion.ihes.fr'])
#emailsExpected.append(['University of California Davis', 'recruit.ucdavis.edu'])
#emailsExpected.append(['University of California Riverside', 'aprecruit.ucr.edu'])
#emailsExpected.append(['University of Missouri Columbia', 'erecruit.umsystem.edu'])
#emailsExpected.append(['Harvard University', 'academicpositions.harvard.edu'])
#emailsExpected.append(['Virginia Tech', 'careers.pageuppeople.com'])
emailsExpected = [['University of Arkansas', 'uasys.wd5.myworkdayjobs.com']]
emailsExpected.append(['University of Sydney', 'usyd.wd3.myworkdayjobs.com'])
emailsExpected.append(['University of Edinburgh', 'elxw.fa.em3.oraclecloud.com'])
emailsExpected = pd.DataFrame(emailsExpected, columns=title)
emailsExpected
# Out:
#                  Institute                      Website
# 0   University of Arkansas  uasys.wd5.myworkdayjobs.com
# 1     University of Sydney   usyd.wd3.myworkdayjobs.com
# 2  University of Edinburgh  elxw.fa.em3.oraclecloud.com

# %%
# I want writers to email letter to
title = ['Deadline', 'Institute', 'Address', 'Info']
#emailsWanted = [['2024/11/01', 'University of Münster', 'mm.applications@uni-muenster.de', '']]
#emailsWanted = [['', 'Worcester Polytechnic Institute', 'ma-chair@wpi.edu', 'Name; Post-Doctoral Scholar of Mathematical Sciences; in Subject']]
#emailsWanted = pd.DataFrame(emailsWanted, columns=title)
#emailsWanted

# %%
# Interviews
jobs['Interview'] = [False for i in range(jobs.shape[0])]
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Münster'),'Interview'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Manitoba'),'Interview'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Saskatchewan'),'Interview'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='University of Tennessee'),'Interview'] = True
jobs.loc[(jobs.Deadline<=applieDate)&(jobs.Institute=='Temple University'),'Interview'] = True
